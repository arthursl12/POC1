# %% [markdown]
# <a href="https://colab.research.google.com/github/arthursl12/POC1/blob/main/POC2_FD002_MLP_optim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# %pip install scikeras;
# %pip install -U tensorflow-addons;
# %pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikeras
#   Downloading scikeras-0.9.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikeras) (1.0.2)
# Requirement already satisfied: importlib-metadata>=3 in /usr/local/lib/python3.7/dist-packages (from scikeras) (4.13.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.7/dist-packages (from scikeras) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=0.21->scikeras) (3.0.9)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 20.5 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 6.0 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.7.3)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0

# %%
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
import datetime

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import GroupKFold

from sklearn.base import BaseEstimator,RegressorMixin

# %%
from skopt import BayesSearchCV

from skopt.space.space import Categorical, Integer, Real

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Masking

from tensorflow.keras.metrics import RootMeanSquaredError as RMSE

from keras.callbacks import LambdaCallback
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.optimizers.schedules import ExponentialDecay

import tensorflow_addons as tfa
from tensorflow_addons.metrics import RSquare as R2

from scikeras.wrappers import KerasRegressor

# %%
sns.set_palette('colorblind')

# %%
# Reproducibility
seed = 42
os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
tf.config.experimental.enable_op_determinism()

# %%
# Remove some tf warnings
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %% [markdown]
# # Data Preparation

# %%
if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    IN_COLAB = True
    folder="/content/CMaps/"

    # Dataset Download 
    os.system('git clone https://github.com/arthursl12/dataset_2')
    os.system('mv /content/dataset_2/CMaps /content/CMaps')
    os.system('mv /content/dataset_2/data_processing /content/data_processing')
    os.system('rm -rf dataset_2')
else:
    print('Not running on CoLab')
    IN_COLAB = False
    folder="CMaps/"
    # %cd dataset_2/
# Out:
# Running on CoLab

# %%
from data_processing.processing import DatasetProcessing
from data_processing.training import HyperparameterSearch, reclipper_scorer
from data_processing.eval import Evaluation

# %%
proc = DatasetProcessing()

# %% [markdown]
# ## Data Integration

# %% [markdown]
# The data are provided as a zip-compressed text file with 26 columns of numbers, separated by spaces. Each row is a snapshot of data taken during a single operational cycle, each column is a different variable. The columns correspond to:
#
# 1) unit number
# 2) time, in cycles
# 3) operational setting 1
# 4) operational setting 2
# 5) operational setting 3
# 6) sensor measurement 1
# 7) sensor measurement 2
# ...
# 26) sensor measurement 20
#
#
# There are 6 conditions (or combinations) which the 3 operational settings can take.
# Condition 1: Altitude = 0, Mach Number = 0, TRA = 100
# Condition 2: Altitude = 10, Mach Number = 0.25, TRA = 100
# Condition 3: Altitude = 20, Mach Number = 0.7 TRA = 100
# Condition 4: Altitude = 25, Mach Number = 0.62, TRA = 60
# Condition 5: Altitude = 35 Mach Number = 0.84, TRA = 100
# Condition 6: Altitude = 42, Mach Number = 0.84, TRA = 100
#
# There is slight variation in all these conditions so you may get numbers like 24.453 instead of 25 exactly.
#
# FD001: Condition 1 only
# FD002: Mix of all the conditions
# FD003: Condition 1 only
# FD004: Mix of all conditions

# %%
index_cols, settings_cols, sensors_cols, cols = proc.column_names()
train, test, y_test = proc.read_dataset(2,folder=folder)
train
# Out:
#        unit_number  time     op_1    op_2   op_3     s_0     s_1      s_2  \
# 0                1     1  34.9983  0.8400  100.0  449.44  555.32  1358.61
# 1                1     2  41.9982  0.8408  100.0  445.00  549.90  1353.22
# 2                1     3  24.9988  0.6218   60.0  462.54  537.31  1256.76
# 3                1     4  42.0077  0.8416  100.0  445.00  549.51  1354.03
# 4                1     5  25.0005  0.6203   60.0  462.54  537.07  1257.71
# ...            ...   ...      ...     ...    ...     ...     ...      ...
# 53754          260   312  20.0037  0.7000  100.0  491.19  608.79  1495.60
# 53755          260   313  10.0022  0.2510  100.0  489.05  605.81  1514.32
# 53756          260   314  25.0041  0.6200   60.0  462.54  537.48  1276.24
# 53757          260   315  25.0033  0.6220   60.0  462.54  537.84  1272.95
# 53758          260   316  35.0036  0.8400  100.0  449.44  556.64  1374.61
#
#            s_3    s_4  ...    s_11     s_12     s_13     s_14  s_15  s_16  \
# 0      1137.23   5.48  ...  183.06  2387.72  8048.56   9.3461  0.02   334
# 1      1125.78   3.91  ...  130.42  2387.66  8072.30   9.3774  0.02   330
# 2      1047.45   7.05  ...  164.22  2028.03  7864.87  10.8941  0.02   309
# 3      1126.38   3.91  ...  130.72  2387.61  8068.66   9.3528  0.02   329
# 4      1047.93   7.05  ...  164.31  2028.00  7861.23  10.8963  0.02   309
# ...        ...    ...  ...     ...      ...      ...      ...   ...   ...
# 53754  1269.51   9.35  ...  314.05  2389.02  8169.64   9.3035  0.03   369
# 53755  1324.12  10.52  ...  371.22  2388.42  8245.36   8.7586  0.03   374
# 53756  1057.92   7.05  ...  163.74  2030.33  7971.25  11.0657  0.02   310
# 53757  1066.30   7.05  ...  164.37  2030.35  7972.47  11.0537  0.02   311
# 53758  1145.52   5.48  ...  183.09  2390.38  8185.35   9.3998  0.02   338
#
#        s_17    s_18   s_19     s_20
# 0      2223  100.00  14.73   8.8071
# 1      2212  100.00  10.41   6.2665
# 2      1915   84.93  14.08   8.6723
# 3      2212  100.00  10.59   6.4701
# 4      1915   84.93  14.13   8.5286
# ...     ...     ...    ...      ...
# 53754  2324  100.00  24.36  14.5189
# 53755  2319  100.00  28.10  16.9454
# 53756  1915   84.93  14.19   8.5503
# 53757  1915   84.93  14.05   8.3729
# 53758  2223  100.00  14.75   8.8446
#
# [53759 rows x 26 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Test Set Transformation
# Test set has samples for all cycles, but has annotations only for last one

# %%
test.shape, y_test.shape
# Out:
# ((33991, 26), (259, 1))

# %%
test_last = proc.transform_test_keep_setting(test)
test_last.head()
# Out:
#       op_1    op_2   op_3     s_0     s_1      s_2      s_3    s_4    s_5  \
# 0  10.0076  0.2501  100.0  489.05  605.42  1515.00  1325.07  10.52  15.50
# 1   0.0018  0.0000  100.0  518.67  642.67  1591.67  1418.17  14.62  21.61
# 2  35.0015  0.8412  100.0  449.44  555.86  1370.62  1135.59   5.48   8.00
# 3  20.0032  0.7000  100.0  491.19  607.99  1487.94  1257.49   9.35  13.66
# 4  42.0055  0.8400  100.0  445.00  550.81  1358.95  1140.34   3.91   5.72
#
#       s_6  ...    s_11     s_12     s_13    s_14  s_15  s_16  s_17   s_18  \
# 0  393.58  ...  370.87  2388.32  8167.06  8.7456  0.03   371  2319  100.0
# 1  553.36  ...  521.10  2388.12  8138.12  8.4248  0.03   393  2388  100.0
# 2  194.58  ...  183.11  2388.07  8071.23  9.3094  0.02   332  2223  100.0
# 3  334.39  ...  314.88  2388.12  8062.39  9.2349  0.02   365  2324  100.0
# 4  138.42  ...  130.82  2389.06  8140.94  9.3964  0.02   333  2212  100.0
#
#     s_19     s_20
# 0  28.30  17.0934
# 1  38.82  23.3463
# 2  14.75   8.9589
# 3  24.22  14.6814
# 4  10.34   6.3601
#
# [5 rows x 24 columns]

# %%
X_test = test_last

# %% [markdown]
# ### Remaining Useful Life (RUL)

# %%
train = proc.add_remaining_useful_life_linear(train)
train[index_cols+['RUL']].head()
# Out:
#    unit_number  time  RUL
# 0            1     1  148
# 1            1     2  147
# 2            1     3  146
# 3            1     4  145
# 4            1     5  144

# %% [markdown]
# ## Attributes and target separation

# %%
X_train, y_train = proc.X_y_train_divide_with_settings(train)

# %%
y_train.head()
# Out:
#    RUL
# 0  148
# 1  147
# 2  146
# 3  145
# 4  144

# %%
X_train.head()
# Out:
#       op_1    op_2   op_3     s_0     s_1      s_2      s_3   s_4   s_5  \
# 0  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23  5.48  8.00
# 1  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78  3.91  5.71
# 2  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45  7.05  9.02
# 3  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38  3.91  5.71
# 4  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93  7.05  9.03
#
#       s_6  ...    s_11     s_12     s_13     s_14  s_15  s_16  s_17    s_18  \
# 0  194.64  ...  183.06  2387.72  8048.56   9.3461  0.02   334  2223  100.00
# 1  138.51  ...  130.42  2387.66  8072.30   9.3774  0.02   330  2212  100.00
# 2  175.71  ...  164.22  2028.03  7864.87  10.8941  0.02   309  1915   84.93
# 3  138.46  ...  130.72  2387.61  8068.66   9.3528  0.02   329  2212  100.00
# 4  175.05  ...  164.31  2028.00  7861.23  10.8963  0.02   309  1915   84.93
#
#     s_19    s_20
# 0  14.73  8.8071
# 1  10.41  6.2665
# 2  14.08  8.6723
# 3  10.59  6.4701
# 4  14.13  8.5286
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Training and Evaluation functions

# %%
eval = Evaluation()

# %%
search = HyperparameterSearch()

# %% [markdown]
# # MLP Construction

# %% [markdown]
# ## Callbacks

# %%
# Early Stopping Callback
es = tf.keras.callbacks.EarlyStopping(monitor='loss', 
                                      patience=5, restore_best_weights=True)

# %%
# Printing Callback
def printLog(epoch, logs):
    print(
        f"E {epoch+1}\t: loss={logs['loss']:.3f}, "+
        f"rmse={logs['root_mean_squared_error']:.3f}, "+
        f"r2={logs['r_square']:.3f}; "+
        f"v_loss={logs['val_loss']:.3f}, "+
        f"v_rmse={logs['val_root_mean_squared_error']:.3f}, "+
        f"v_r2={logs['val_r_square']:.3f}; "
    )

printerCallback = LambdaCallback(on_epoch_end=printLog)

# %% [markdown]
# ## Constants

# %%
# X_train must include indices
train3 = train.copy()
X_train_ = train3.drop(columns=[index_cols[1]]+["RUL"])

# %%
INPUT_SHAPE = 0

# %% [markdown]
# ## Wrapper

# %%
from sys import is_finalizing
from sklearn.metrics import r2_score

class MLPWrapperRegressor(BaseEstimator,RegressorMixin):
    def __init__(self, basemodel=None, clip_y=-1,
                 include_settings=False, poly_degree=1,
                 scaler=StandardScaler()):
        # Base parameters
        self.basemodel = basemodel
        self.clip_y = clip_y
        self.poly_degree = poly_degree
        self.include_settings = include_settings

        # Column indexers
        self.feature_cols = sensors_cols
        if(include_settings):
            self.feature_cols = settings_cols + self.feature_cols
        self.base_feature_cols = self.feature_cols

        # Scaler and PolyFeatures transformers
        self.scaler = scaler
        self.polyft = PolynomialFeatures(degree=self.poly_degree, 
                                         include_bias=False)

    def clean_cols(self,df):
        if("unit_number" in df.columns): del df["unit_number"]
        if("unit_number" in df.columns): del df["unit_number"]
        if("time" in df.columns): del df["time"]
        if((not self.include_settings)): 
            for col in settings_cols:
                if(col in df.columns): del df[col]
        return df

    def fit(self, X=None, y=None):
        # Drop irrelevant column
        data = pd.DataFrame(X).copy()
        data = self.clean_cols(data)
        
        # Apply polynomial features and add them to the dataframe
        transf = self.polyft.fit_transform(data)
        data = pd.DataFrame(transf, columns=
                              self.polyft.get_feature_names_out())
        self.feature_cols = list(self.polyft.get_feature_names_out())

        # Scale the data
        data = self.scaler.fit_transform(data)
        data = pd.DataFrame(data, 
                            columns=self.scaler.get_feature_names_out())
        X_train = data.copy()
        
        # Clip and transform labels
        data2 = pd.DataFrame(y, columns=["RUL"]).copy()
        if (self.clip_y > 0):
            data2["RUL"].clip(upper=self.clip_y, inplace=True)
        y_train = data2

        # Update input shape for future use
        global INPUT_SHAPE
        INPUT_SHAPE = X_train.shape[1]

        # Fit model
        self.basemodel.fit(X_train,y_train)
        return self
        
    def predict(self, X=None):
        # Perform transformation, if not done
        if (len(X.columns) != len(self.feature_cols)):
            X_train = self.transform_features(X)
        else:
            X_train = X
        return self.basemodel.predict(X_train)

    def transform_features(self, df):
        # Drop irrelevant column
        data = pd.DataFrame(df).copy()
        data = self.clean_cols(data)
        
        # Apply polynomial features and add them to the dataframe
        transf = self.polyft.transform(data)
        data = pd.DataFrame(transf, columns=
                              self.polyft.get_feature_names_out())
        # self.feature_cols = list(self.polyft.get_feature_names_out())

        # Scale the data
        data = self.scaler.transform(data)
        data = pd.DataFrame(data, 
                            columns=self.scaler.get_feature_names_out())
        return data

    def score(self, X, y, sample_weight=None):
        X_test = self.transform_features(X)

        # Clip and transform labels
        data2 = pd.DataFrame(y, columns=["RUL"]).copy()
        if (self.clip_y > 0):
            data2["RUL"].clip(upper=self.clip_y, inplace=True)
        y_test = data2

        # Predict on test data
        y_pred = self.predict(X_test)
        return r2_score(y_test, y_pred, sample_weight=sample_weight)

# %% [markdown]
# ## Test Data

# %%
def scale_test(test,model):
    test2 = pd.DataFrame(test)
    test2 = model.clean_cols(test2)

    # Apply polynomial features
    transf = model.polyft.transform(test2)
    test2 = pd.DataFrame(transf, 
                         columns=model.polyft.get_feature_names_out())

    # Scale the data (with train data parameters)
    test2 = model.scaler.transform(test2)
    test2 = pd.DataFrame(test2, 
                         columns=model.polyft.get_feature_names_out())
    return test2

# %% [markdown]
# ## Constructor

# %%
def create_model(optim=Adam, learning_rate=1e-3, 
                 layer1=32  , activation1="tanh"    , dropout1=0.1,
                 layer2=None, activation2="tanh"    , dropout2=0.1,
                 layer3=None, activation3="tanh"    , dropout3=0.1,
                 layer4=None, activation4="tanh"    , dropout4=0.1,
                 print_summary=False, loss='mean_squared_error',
                 metrics=[tf.keras.metrics.MeanSquaredError()]):
    model = Sequential()

    # Fully Connected Layer
    model.add(Dense(layer1, input_dim=INPUT_SHAPE, activation=activation1))
    model.add(Dropout(dropout1))

    # Additional hidden layers
    if(layer2 is not None):
        model.add(Dense(layer2, activation=activation2))
        model.add(Dropout(dropout2))
        if (layer3 is not None):
            model.add(Dense(layer3, activation=activation3))
            model.add(Dropout(dropout3))
            if (layer4 is not None):
                model.add(Dense(layer4, activation=activation4))
                model.add(Dropout(dropout4))

    # Output Layer
    model.add(Dense(1))

    model.compile(loss=loss, optimizer=optim(learning_rate=learning_rate), 
                  metrics=metrics)
    
    if(print_summary): model.summary()
    return model

# %% [markdown]
# # HyperParameter Tuning

# %%
CLIP=126

model = MLPWrapperRegressor(
        clip_y=CLIP,scaler=MinMaxScaler(),
        include_settings=True,
        basemodel=
            KerasRegressor(model=create_model,
                           batch_size=64,
                           epochs=1,
                           validation_split=0.2, 
                           model__layer1=512, 
                           model__activation1='relu',
                           model__dropout1=0.5, 
                           model__layer2=64,
                           model__layer3=64,
                           model__layer4=64,
                           model__learning_rate=0.01,
                           model__optim=Adam,
                        #    verbose=0, callbacks=[es,printerCallback],
                           verbose=0, callbacks=[es],
                           model__metrics=[RMSE(), R2()],
                           model__loss='mse',
                           print_summary=False
                           )
    )

# %%
# ~3h (LSTM)
# ~45min (MLP)
GRID_SEARCH = True
if (GRID_SEARCH):
    param_distributions = {
        "include_settings": Categorical([True]),
        "clip_y": Integer(80,140),
        "poly_degree": Categorical([2,3]),
        "scaler": Categorical([MinMaxScaler(),StandardScaler()]),
        "basemodel__epochs": Integer(1,50),
        "basemodel__validation_split":Real(0.1,0.9),
        "basemodel__batch_size": Integer(32,512),
        "basemodel__model__optim":Categorical([Adam,RMSprop]),
        "basemodel__model__learning_rate": Real(1e-4, 1e-2),
        
        "basemodel__model__layer1": Integer(16,512),
        "basemodel__model__activation1": Categorical(["relu","elu","selu","tanh", "sigmoid"]),
        "basemodel__model__dropout1": Real(0.1,0.9),

        "basemodel__model__layer2": Integer(16,512),
        "basemodel__model__activation2": Categorical(["relu","elu","selu","tanh", "sigmoid"]),
        "basemodel__model__dropout2": Real(0.1,0.9),

        "basemodel__model__layer3": Integer(16,512),
        "basemodel__model__activation3": Categorical(["relu","elu","selu","tanh", "sigmoid"]),
        "basemodel__model__dropout3": Real(0.1,0.9),

        "basemodel__model__layer4": Integer(16,512),
        "basemodel__model__activation4": Categorical(["relu","elu","selu","tanh", "sigmoid"]),
        "basemodel__model__dropout4": Real(0.1,0.9),
    }
    gcv = GroupKFold(n_splits=3)
    groups=X_train_['unit_number']
    bss = BayesSearchCV(model, param_distributions, 
                        verbose=3, n_jobs=1, refit=False,
                        cv=gcv.split(X_train_, groups=groups), n_iter=45)
    model = bss.fit(X_train_, y_train)
    
    # print(bss.best_estimator_)
    print("Finished:", datetime.datetime.now())
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=229, basemodel__epochs=37, basemodel__model__activation1=tanh, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.3807450679193153, basemodel__model__dropout2=0.6916033873523364, basemodel__model__dropout3=0.34357064882920496, basemodel__model__dropout4=0.6182332706775021, basemodel__model__layer1=289, basemodel__model__layer2=79, basemodel__model__layer3=104, basemodel__model__layer4=330, basemodel__model__learning_rate=0.0008711231684588401, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6461978023075464, clip_y=126, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.538 total time=  23.6s
# [CV 2/3] END basemodel__batch_size=229, basemodel__epochs=37, basemodel__model__activation1=tanh, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.3807450679193153, basemodel__model__dropout2=0.6916033873523364, basemodel__model__dropout3=0.34357064882920496, basemodel__model__dropout4=0.6182332706775021, basemodel__model__layer1=289, basemodel__model__layer2=79, basemodel__model__layer3=104, basemodel__model__layer4=330, basemodel__model__learning_rate=0.0008711231684588401, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6461978023075464, clip_y=126, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.647 total time=  21.6s
# [CV 3/3] END basemodel__batch_size=229, basemodel__epochs=37, basemodel__model__activation1=tanh, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.3807450679193153, basemodel__model__dropout2=0.6916033873523364, basemodel__model__dropout3=0.34357064882920496, basemodel__model__dropout4=0.6182332706775021, basemodel__model__layer1=289, basemodel__model__layer2=79, basemodel__model__layer3=104, basemodel__model__layer4=330, basemodel__model__learning_rate=0.0008711231684588401, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6461978023075464, clip_y=126, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.587 total time=  19.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=434, basemodel__epochs=44, basemodel__model__activation1=relu, basemodel__model__activation2=tanh, basemodel__model__activation3=sigmoid, basemodel__model__activation4=elu, basemodel__model__dropout1=0.21064683062286016, basemodel__model__dropout2=0.3828699181027345, basemodel__model__dropout3=0.6085832815033363, basemodel__model__dropout4=0.862784120151835, basemodel__model__layer1=328, basemodel__model__layer2=508, basemodel__model__layer3=396, basemodel__model__layer4=209, basemodel__model__learning_rate=0.006112477731449117, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13825434020683042, clip_y=121, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.005 total time=   4.3s
# [CV 2/3] END basemodel__batch_size=434, basemodel__epochs=44, basemodel__model__activation1=relu, basemodel__model__activation2=tanh, basemodel__model__activation3=sigmoid, basemodel__model__activation4=elu, basemodel__model__dropout1=0.21064683062286016, basemodel__model__dropout2=0.3828699181027345, basemodel__model__dropout3=0.6085832815033363, basemodel__model__dropout4=0.862784120151835, basemodel__model__layer1=328, basemodel__model__layer2=508, basemodel__model__layer3=396, basemodel__model__layer4=209, basemodel__model__learning_rate=0.006112477731449117, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13825434020683042, clip_y=121, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.000 total time=   6.0s
# [CV 3/3] END basemodel__batch_size=434, basemodel__epochs=44, basemodel__model__activation1=relu, basemodel__model__activation2=tanh, basemodel__model__activation3=sigmoid, basemodel__model__activation4=elu, basemodel__model__dropout1=0.21064683062286016, basemodel__model__dropout2=0.3828699181027345, basemodel__model__dropout3=0.6085832815033363, basemodel__model__dropout4=0.862784120151835, basemodel__model__layer1=328, basemodel__model__layer2=508, basemodel__model__layer3=396, basemodel__model__layer4=209, basemodel__model__learning_rate=0.006112477731449117, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13825434020683042, clip_y=121, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.001 total time=   3.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=246, basemodel__epochs=46, basemodel__model__activation1=elu, basemodel__model__activation2=selu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.22435844324043466, basemodel__model__dropout2=0.7012420250723972, basemodel__model__dropout3=0.5458723384270411, basemodel__model__dropout4=0.878565582154311, basemodel__model__layer1=365, basemodel__model__layer2=205, basemodel__model__layer3=114, basemodel__model__layer4=269, basemodel__model__learning_rate=0.004508929401410197, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.8975239431771755, clip_y=94, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.556 total time=  13.9s
# [CV 2/3] END basemodel__batch_size=246, basemodel__epochs=46, basemodel__model__activation1=elu, basemodel__model__activation2=selu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.22435844324043466, basemodel__model__dropout2=0.7012420250723972, basemodel__model__dropout3=0.5458723384270411, basemodel__model__dropout4=0.878565582154311, basemodel__model__layer1=365, basemodel__model__layer2=205, basemodel__model__layer3=114, basemodel__model__layer4=269, basemodel__model__learning_rate=0.004508929401410197, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.8975239431771755, clip_y=94, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.440 total time=   9.5s
# [CV 3/3] END basemodel__batch_size=246, basemodel__epochs=46, basemodel__model__activation1=elu, basemodel__model__activation2=selu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.22435844324043466, basemodel__model__dropout2=0.7012420250723972, basemodel__model__dropout3=0.5458723384270411, basemodel__model__dropout4=0.878565582154311, basemodel__model__layer1=365, basemodel__model__layer2=205, basemodel__model__layer3=114, basemodel__model__layer4=269, basemodel__model__learning_rate=0.004508929401410197, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.8975239431771755, clip_y=94, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.164 total time=  11.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=422, basemodel__epochs=9, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.7046404262687053, basemodel__model__dropout2=0.7981042826479537, basemodel__model__dropout3=0.829543089205507, basemodel__model__dropout4=0.409436211374147, basemodel__model__layer1=185, basemodel__model__layer2=431, basemodel__model__layer3=319, basemodel__model__layer4=29, basemodel__model__learning_rate=0.009650535848048808, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.351270093972768, clip_y=84, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=0.364 total time=   3.5s
# [CV 2/3] END basemodel__batch_size=422, basemodel__epochs=9, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.7046404262687053, basemodel__model__dropout2=0.7981042826479537, basemodel__model__dropout3=0.829543089205507, basemodel__model__dropout4=0.409436211374147, basemodel__model__layer1=185, basemodel__model__layer2=431, basemodel__model__layer3=319, basemodel__model__layer4=29, basemodel__model__learning_rate=0.009650535848048808, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.351270093972768, clip_y=84, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=0.503 total time=   3.8s
# [CV 3/3] END basemodel__batch_size=422, basemodel__epochs=9, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.7046404262687053, basemodel__model__dropout2=0.7981042826479537, basemodel__model__dropout3=0.829543089205507, basemodel__model__dropout4=0.409436211374147, basemodel__model__layer1=185, basemodel__model__layer2=431, basemodel__model__layer3=319, basemodel__model__layer4=29, basemodel__model__learning_rate=0.009650535848048808, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.351270093972768, clip_y=84, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=0.499 total time=   3.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=416, basemodel__epochs=22, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=tanh, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.43934245796854565, basemodel__model__dropout2=0.6202272813982102, basemodel__model__dropout3=0.3824670764223771, basemodel__model__dropout4=0.6275409829592771, basemodel__model__layer1=270, basemodel__model__layer2=454, basemodel__model__layer3=143, basemodel__model__layer4=147, basemodel__model__learning_rate=0.002752075144662172, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.1333448236351461, clip_y=110, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=-0.002 total time=   6.3s
# [CV 2/3] END basemodel__batch_size=416, basemodel__epochs=22, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=tanh, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.43934245796854565, basemodel__model__dropout2=0.6202272813982102, basemodel__model__dropout3=0.3824670764223771, basemodel__model__dropout4=0.6275409829592771, basemodel__model__layer1=270, basemodel__model__layer2=454, basemodel__model__layer3=143, basemodel__model__layer4=147, basemodel__model__learning_rate=0.002752075144662172, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.1333448236351461, clip_y=110, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.480 total time=  11.3s
# [CV 3/3] END basemodel__batch_size=416, basemodel__epochs=22, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=tanh, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.43934245796854565, basemodel__model__dropout2=0.6202272813982102, basemodel__model__dropout3=0.3824670764223771, basemodel__model__dropout4=0.6275409829592771, basemodel__model__layer1=270, basemodel__model__layer2=454, basemodel__model__layer3=143, basemodel__model__layer4=147, basemodel__model__learning_rate=0.002752075144662172, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.1333448236351461, clip_y=110, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=-0.000 total time=  11.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=384, basemodel__epochs=47, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=relu, basemodel__model__dropout1=0.4672196113206446, basemodel__model__dropout2=0.5278121280969085, basemodel__model__dropout3=0.7282271497139966, basemodel__model__dropout4=0.545941762910148, basemodel__model__layer1=308, basemodel__model__layer2=296, basemodel__model__layer3=27, basemodel__model__layer4=263, basemodel__model__learning_rate=0.009684924322508254, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6176050085048632, clip_y=137, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.096 total time=  11.2s
# [CV 2/3] END basemodel__batch_size=384, basemodel__epochs=47, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=relu, basemodel__model__dropout1=0.4672196113206446, basemodel__model__dropout2=0.5278121280969085, basemodel__model__dropout3=0.7282271497139966, basemodel__model__dropout4=0.545941762910148, basemodel__model__layer1=308, basemodel__model__layer2=296, basemodel__model__layer3=27, basemodel__model__layer4=263, basemodel__model__learning_rate=0.009684924322508254, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6176050085048632, clip_y=137, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.250 total time=   5.6s
# [CV 3/3] END basemodel__batch_size=384, basemodel__epochs=47, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=relu, basemodel__model__dropout1=0.4672196113206446, basemodel__model__dropout2=0.5278121280969085, basemodel__model__dropout3=0.7282271497139966, basemodel__model__dropout4=0.545941762910148, basemodel__model__layer1=308, basemodel__model__layer2=296, basemodel__model__layer3=27, basemodel__model__layer4=263, basemodel__model__learning_rate=0.009684924322508254, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6176050085048632, clip_y=137, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.193 total time=   5.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=328, basemodel__epochs=39, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.6190220077629807, basemodel__model__dropout2=0.4376660687605579, basemodel__model__dropout3=0.6871059882150446, basemodel__model__dropout4=0.6074396569146396, basemodel__model__layer1=474, basemodel__model__layer2=342, basemodel__model__layer3=319, basemodel__model__layer4=188, basemodel__model__learning_rate=0.004738304085888927, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.36189333612951236, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.744 total time=  16.3s
# [CV 2/3] END basemodel__batch_size=328, basemodel__epochs=39, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.6190220077629807, basemodel__model__dropout2=0.4376660687605579, basemodel__model__dropout3=0.6871059882150446, basemodel__model__dropout4=0.6074396569146396, basemodel__model__layer1=474, basemodel__model__layer2=342, basemodel__model__layer3=319, basemodel__model__layer4=188, basemodel__model__learning_rate=0.004738304085888927, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.36189333612951236, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.542 total time=  21.7s
# [CV 3/3] END basemodel__batch_size=328, basemodel__epochs=39, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.6190220077629807, basemodel__model__dropout2=0.4376660687605579, basemodel__model__dropout3=0.6871059882150446, basemodel__model__dropout4=0.6074396569146396, basemodel__model__layer1=474, basemodel__model__layer2=342, basemodel__model__layer3=319, basemodel__model__layer4=188, basemodel__model__learning_rate=0.004738304085888927, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.36189333612951236, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.756 total time=  15.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=293, basemodel__epochs=46, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=relu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.5566222421431186, basemodel__model__dropout2=0.12064086804281687, basemodel__model__dropout3=0.4085836727877318, basemodel__model__dropout4=0.7607567651583368, basemodel__model__layer1=198, basemodel__model__layer2=300, basemodel__model__layer3=358, basemodel__model__layer4=54, basemodel__model__learning_rate=0.0028174657490377245, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.7792276334276748, clip_y=82, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.586 total time=  21.6s
# [CV 2/3] END basemodel__batch_size=293, basemodel__epochs=46, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=relu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.5566222421431186, basemodel__model__dropout2=0.12064086804281687, basemodel__model__dropout3=0.4085836727877318, basemodel__model__dropout4=0.7607567651583368, basemodel__model__layer1=198, basemodel__model__layer2=300, basemodel__model__layer3=358, basemodel__model__layer4=54, basemodel__model__learning_rate=0.0028174657490377245, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.7792276334276748, clip_y=82, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.462 total time=  21.7s
# [CV 3/3] END basemodel__batch_size=293, basemodel__epochs=46, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=relu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.5566222421431186, basemodel__model__dropout2=0.12064086804281687, basemodel__model__dropout3=0.4085836727877318, basemodel__model__dropout4=0.7607567651583368, basemodel__model__layer1=198, basemodel__model__layer2=300, basemodel__model__layer3=358, basemodel__model__layer4=54, basemodel__model__learning_rate=0.0028174657490377245, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.7792276334276748, clip_y=82, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.527 total time=  21.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=491, basemodel__epochs=35, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.1000488406021388, basemodel__model__dropout2=0.3965483901301635, basemodel__model__dropout3=0.5755031308731086, basemodel__model__dropout4=0.24072512447023642, basemodel__model__layer1=397, basemodel__model__layer2=236, basemodel__model__layer3=78, basemodel__model__layer4=108, basemodel__model__learning_rate=0.003739593550034222, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6969019934333063, clip_y=137, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=0.053 total time=   8.6s
# [CV 2/3] END basemodel__batch_size=491, basemodel__epochs=35, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.1000488406021388, basemodel__model__dropout2=0.3965483901301635, basemodel__model__dropout3=0.5755031308731086, basemodel__model__dropout4=0.24072512447023642, basemodel__model__layer1=397, basemodel__model__layer2=236, basemodel__model__layer3=78, basemodel__model__layer4=108, basemodel__model__learning_rate=0.003739593550034222, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6969019934333063, clip_y=137, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=-0.095 total time=   9.5s
# [CV 3/3] END basemodel__batch_size=491, basemodel__epochs=35, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.1000488406021388, basemodel__model__dropout2=0.3965483901301635, basemodel__model__dropout3=0.5755031308731086, basemodel__model__dropout4=0.24072512447023642, basemodel__model__layer1=397, basemodel__model__layer2=236, basemodel__model__layer3=78, basemodel__model__layer4=108, basemodel__model__learning_rate=0.003739593550034222, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.6969019934333063, clip_y=137, include_settings=True, poly_degree=3, scaler=MinMaxScaler();, score=-0.156 total time=   6.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=34, basemodel__epochs=41, basemodel__model__activation1=sigmoid, basemodel__model__activation2=relu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3502714449877026, basemodel__model__dropout2=0.22207566947075547, basemodel__model__dropout3=0.8150704488420156, basemodel__model__dropout4=0.7506219716105309, basemodel__model__layer1=390, basemodel__model__layer2=26, basemodel__model__layer3=133, basemodel__model__layer4=375, basemodel__model__learning_rate=0.004578678481029758, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.23331974650437462, clip_y=117, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-0.618 total time= 2.2min
# [CV 2/3] END basemodel__batch_size=34, basemodel__epochs=41, basemodel__model__activation1=sigmoid, basemodel__model__activation2=relu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3502714449877026, basemodel__model__dropout2=0.22207566947075547, basemodel__model__dropout3=0.8150704488420156, basemodel__model__dropout4=0.7506219716105309, basemodel__model__layer1=390, basemodel__model__layer2=26, basemodel__model__layer3=133, basemodel__model__layer4=375, basemodel__model__learning_rate=0.004578678481029758, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.23331974650437462, clip_y=117, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-1.806 total time= 2.2min
# [CV 3/3] END basemodel__batch_size=34, basemodel__epochs=41, basemodel__model__activation1=sigmoid, basemodel__model__activation2=relu, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3502714449877026, basemodel__model__dropout2=0.22207566947075547, basemodel__model__dropout3=0.8150704488420156, basemodel__model__dropout4=0.7506219716105309, basemodel__model__layer1=390, basemodel__model__layer2=26, basemodel__model__layer3=133, basemodel__model__layer4=375, basemodel__model__learning_rate=0.004578678481029758, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.23331974650437462, clip_y=117, include_settings=True, poly_degree=2, scaler=MinMaxScaler();, score=-1.824 total time= 2.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=303, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8073312270351377, basemodel__model__dropout2=0.4092975438454226, basemodel__model__dropout3=0.5928059239393538, basemodel__model__dropout4=0.4387265867177964, basemodel__model__layer1=454, basemodel__model__layer2=263, basemodel__model__layer3=361, basemodel__model__layer4=227, basemodel__model__learning_rate=0.0027797938736704064, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.14045307766738713, clip_y=123, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.585 total time=  19.3s
# [CV 2/3] END basemodel__batch_size=303, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8073312270351377, basemodel__model__dropout2=0.4092975438454226, basemodel__model__dropout3=0.5928059239393538, basemodel__model__dropout4=0.4387265867177964, basemodel__model__layer1=454, basemodel__model__layer2=263, basemodel__model__layer3=361, basemodel__model__layer4=227, basemodel__model__learning_rate=0.0027797938736704064, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.14045307766738713, clip_y=123, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.603 total time=  15.3s
# [CV 3/3] END basemodel__batch_size=303, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8073312270351377, basemodel__model__dropout2=0.4092975438454226, basemodel__model__dropout3=0.5928059239393538, basemodel__model__dropout4=0.4387265867177964, basemodel__model__layer1=454, basemodel__model__layer2=263, basemodel__model__layer3=361, basemodel__model__layer4=227, basemodel__model__learning_rate=0.0027797938736704064, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.14045307766738713, clip_y=123, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.610 total time=  15.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=273, basemodel__epochs=5, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3372125774342486, basemodel__model__dropout2=0.10270263000059235, basemodel__model__dropout3=0.15317377129548915, basemodel__model__dropout4=0.7829376163566086, basemodel__model__layer1=430, basemodel__model__layer2=165, basemodel__model__layer3=305, basemodel__model__layer4=112, basemodel__model__learning_rate=0.0028234159917996902, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.23930934006811333, clip_y=109, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.665 total time=   3.2s
# [CV 2/3] END basemodel__batch_size=273, basemodel__epochs=5, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3372125774342486, basemodel__model__dropout2=0.10270263000059235, basemodel__model__dropout3=0.15317377129548915, basemodel__model__dropout4=0.7829376163566086, basemodel__model__layer1=430, basemodel__model__layer2=165, basemodel__model__layer3=305, basemodel__model__layer4=112, basemodel__model__learning_rate=0.0028234159917996902, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.23930934006811333, clip_y=109, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.721 total time=   3.5s
# [CV 3/3] END basemodel__batch_size=273, basemodel__epochs=5, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3372125774342486, basemodel__model__dropout2=0.10270263000059235, basemodel__model__dropout3=0.15317377129548915, basemodel__model__dropout4=0.7829376163566086, basemodel__model__layer1=430, basemodel__model__layer2=165, basemodel__model__layer3=305, basemodel__model__layer4=112, basemodel__model__learning_rate=0.0028234159917996902, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.23930934006811333, clip_y=109, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.636 total time=   3.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=344, basemodel__epochs=41, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.5207780657079589, basemodel__model__dropout2=0.5121720374267245, basemodel__model__dropout3=0.7654641227150226, basemodel__model__dropout4=0.6329812264783566, basemodel__model__layer1=512, basemodel__model__layer2=372, basemodel__model__layer3=293, basemodel__model__layer4=219, basemodel__model__learning_rate=0.006742388079627567, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.3907594508854241, clip_y=97, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.664 total time=  21.7s
# [CV 2/3] END basemodel__batch_size=344, basemodel__epochs=41, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.5207780657079589, basemodel__model__dropout2=0.5121720374267245, basemodel__model__dropout3=0.7654641227150226, basemodel__model__dropout4=0.6329812264783566, basemodel__model__layer1=512, basemodel__model__layer2=372, basemodel__model__layer3=293, basemodel__model__layer4=219, basemodel__model__learning_rate=0.006742388079627567, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.3907594508854241, clip_y=97, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.712 total time=  21.6s
# [CV 3/3] END basemodel__batch_size=344, basemodel__epochs=41, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.5207780657079589, basemodel__model__dropout2=0.5121720374267245, basemodel__model__dropout3=0.7654641227150226, basemodel__model__dropout4=0.6329812264783566, basemodel__model__layer1=512, basemodel__model__layer2=372, basemodel__model__layer3=293, basemodel__model__layer4=219, basemodel__model__learning_rate=0.006742388079627567, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.3907594508854241, clip_y=97, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.706 total time=  15.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=32, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=tanh, basemodel__model__activation4=elu, basemodel__model__dropout1=0.9, basemodel__model__dropout2=0.9, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.9, basemodel__model__layer1=512, basemodel__model__layer2=16, basemodel__model__layer3=512, basemodel__model__layer4=512, basemodel__model__learning_rate=0.01, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-2.155 total time=   6.8s
# [CV 2/3] END basemodel__batch_size=32, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=tanh, basemodel__model__activation4=elu, basemodel__model__dropout1=0.9, basemodel__model__dropout2=0.9, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.9, basemodel__model__layer1=512, basemodel__model__layer2=16, basemodel__model__layer3=512, basemodel__model__layer4=512, basemodel__model__learning_rate=0.01, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-1.932 total time=   7.2s
# [CV 3/3] END basemodel__batch_size=32, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=tanh, basemodel__model__activation3=tanh, basemodel__model__activation4=elu, basemodel__model__dropout1=0.9, basemodel__model__dropout2=0.9, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.9, basemodel__model__layer1=512, basemodel__model__layer2=16, basemodel__model__layer3=512, basemodel__model__layer4=512, basemodel__model__learning_rate=0.01, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-2.225 total time=   7.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=261, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.21150409683680838, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.1, basemodel__model__dropout4=0.9, basemodel__model__layer1=508, basemodel__model__layer2=114, basemodel__model__layer3=332, basemodel__model__layer4=109, basemodel__model__learning_rate=0.0005211596311562694, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.19192415976066293, clip_y=116, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=-0.182 total time=   1.6s
# [CV 2/3] END basemodel__batch_size=261, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.21150409683680838, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.1, basemodel__model__dropout4=0.9, basemodel__model__layer1=508, basemodel__model__layer2=114, basemodel__model__layer3=332, basemodel__model__layer4=109, basemodel__model__learning_rate=0.0005211596311562694, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.19192415976066293, clip_y=116, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=-0.048 total time=   1.6s
# [CV 3/3] END basemodel__batch_size=261, basemodel__epochs=1, basemodel__model__activation1=elu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.21150409683680838, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.1, basemodel__model__dropout4=0.9, basemodel__model__layer1=508, basemodel__model__layer2=114, basemodel__model__layer3=332, basemodel__model__layer4=109, basemodel__model__learning_rate=0.0005211596311562694, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.19192415976066293, clip_y=116, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=-0.177 total time=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=310, basemodel__epochs=50, basemodel__model__activation1=tanh, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=tanh, basemodel__model__dropout1=0.7615078972204509, basemodel__model__dropout2=0.8676452455637333, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.2759536964629361, basemodel__model__layer1=432, basemodel__model__layer2=388, basemodel__model__layer3=260, basemodel__model__layer4=266, basemodel__model__learning_rate=0.005843285817970125, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6688472541535271, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-0.001 total time=   5.0s
# [CV 2/3] END basemodel__batch_size=310, basemodel__epochs=50, basemodel__model__activation1=tanh, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=tanh, basemodel__model__dropout1=0.7615078972204509, basemodel__model__dropout2=0.8676452455637333, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.2759536964629361, basemodel__model__layer1=432, basemodel__model__layer2=388, basemodel__model__layer3=260, basemodel__model__layer4=266, basemodel__model__learning_rate=0.005843285817970125, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6688472541535271, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-0.001 total time=   8.2s
# [CV 3/3] END basemodel__batch_size=310, basemodel__epochs=50, basemodel__model__activation1=tanh, basemodel__model__activation2=tanh, basemodel__model__activation3=relu, basemodel__model__activation4=tanh, basemodel__model__dropout1=0.7615078972204509, basemodel__model__dropout2=0.8676452455637333, basemodel__model__dropout3=0.9, basemodel__model__dropout4=0.2759536964629361, basemodel__model__layer1=432, basemodel__model__layer2=388, basemodel__model__layer3=260, basemodel__model__layer4=266, basemodel__model__learning_rate=0.005843285817970125, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.6688472541535271, clip_y=80, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-0.003 total time=   7.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=273, basemodel__epochs=1, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.27968577632818703, basemodel__model__dropout2=0.278819086570095, basemodel__model__dropout3=0.16811599660703333, basemodel__model__dropout4=0.7599139729265101, basemodel__model__layer1=499, basemodel__model__layer2=158, basemodel__model__layer3=270, basemodel__model__layer4=156, basemodel__model__learning_rate=0.004847408824445868, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13229141719115572, clip_y=117, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.582 total time=   1.6s
# [CV 2/3] END basemodel__batch_size=273, basemodel__epochs=1, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.27968577632818703, basemodel__model__dropout2=0.278819086570095, basemodel__model__dropout3=0.16811599660703333, basemodel__model__dropout4=0.7599139729265101, basemodel__model__layer1=499, basemodel__model__layer2=158, basemodel__model__layer3=270, basemodel__model__layer4=156, basemodel__model__learning_rate=0.004847408824445868, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13229141719115572, clip_y=117, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.421 total time=   1.6s
# [CV 3/3] END basemodel__batch_size=273, basemodel__epochs=1, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=selu, basemodel__model__dropout1=0.27968577632818703, basemodel__model__dropout2=0.278819086570095, basemodel__model__dropout3=0.16811599660703333, basemodel__model__dropout4=0.7599139729265101, basemodel__model__layer1=499, basemodel__model__layer2=158, basemodel__model__layer3=270, basemodel__model__layer4=156, basemodel__model__learning_rate=0.004847408824445868, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.13229141719115572, clip_y=117, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.405 total time=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=278, basemodel__epochs=6, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3760030665032811, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.16306667698988347, basemodel__model__dropout4=0.75677854272187, basemodel__model__layer1=405, basemodel__model__layer2=187, basemodel__model__layer3=300, basemodel__model__layer4=103, basemodel__model__learning_rate=0.0034205920470761686, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.25718672895654293, clip_y=106, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.649 total time=   6.1s
# [CV 2/3] END basemodel__batch_size=278, basemodel__epochs=6, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3760030665032811, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.16306667698988347, basemodel__model__dropout4=0.75677854272187, basemodel__model__layer1=405, basemodel__model__layer2=187, basemodel__model__layer3=300, basemodel__model__layer4=103, basemodel__model__learning_rate=0.0034205920470761686, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.25718672895654293, clip_y=106, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.622 total time=   6.1s
# [CV 3/3] END basemodel__batch_size=278, basemodel__epochs=6, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.3760030665032811, basemodel__model__dropout2=0.1, basemodel__model__dropout3=0.16306667698988347, basemodel__model__dropout4=0.75677854272187, basemodel__model__layer1=405, basemodel__model__layer2=187, basemodel__model__layer3=300, basemodel__model__layer4=103, basemodel__model__learning_rate=0.0034205920470761686, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.25718672895654293, clip_y=106, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.674 total time=   6.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=298, basemodel__epochs=7, basemodel__model__activation1=selu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.40933590179952284, basemodel__model__dropout2=0.11318734691633264, basemodel__model__dropout3=0.16913694014288042, basemodel__model__dropout4=0.6968920639082488, basemodel__model__layer1=380, basemodel__model__layer2=213, basemodel__model__layer3=287, basemodel__model__layer4=103, basemodel__model__learning_rate=0.004406466059029638, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2639682152140967, clip_y=105, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.706 total time=   6.1s
# [CV 2/3] END basemodel__batch_size=298, basemodel__epochs=7, basemodel__model__activation1=selu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.40933590179952284, basemodel__model__dropout2=0.11318734691633264, basemodel__model__dropout3=0.16913694014288042, basemodel__model__dropout4=0.6968920639082488, basemodel__model__layer1=380, basemodel__model__layer2=213, basemodel__model__layer3=287, basemodel__model__layer4=103, basemodel__model__learning_rate=0.004406466059029638, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2639682152140967, clip_y=105, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.698 total time=   6.1s
# [CV 3/3] END basemodel__batch_size=298, basemodel__epochs=7, basemodel__model__activation1=selu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.40933590179952284, basemodel__model__dropout2=0.11318734691633264, basemodel__model__dropout3=0.16913694014288042, basemodel__model__dropout4=0.6968920639082488, basemodel__model__layer1=380, basemodel__model__layer2=213, basemodel__model__layer3=287, basemodel__model__layer4=103, basemodel__model__learning_rate=0.004406466059029638, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2639682152140967, clip_y=105, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.747 total time=   4.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=285, basemodel__epochs=6, basemodel__model__activation1=selu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.39841173295792653, basemodel__model__dropout2=0.17723030707998255, basemodel__model__dropout3=0.1912277446296065, basemodel__model__dropout4=0.6819298111744312, basemodel__model__layer1=406, basemodel__model__layer2=175, basemodel__model__layer3=267, basemodel__model__layer4=145, basemodel__model__learning_rate=0.0054398491235536535, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.20916985091752902, clip_y=109, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.705 total time=   3.5s
# [CV 2/3] END basemodel__batch_size=285, basemodel__epochs=6, basemodel__model__activation1=selu, basemodel__model__activation2=relu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.39841173295792653, basemodel__model__dropout2=0.17723030707998255, basemodel__model__dropout3=0.1912277446296065, basemodel__model__dropout4=0.6819298111744312, basemodel__model__layer1=406, basemodel__model__layer2=175, basemodel__model__layer3=267, basemodel__model__layer4=145, basemodel__model__learning_rate=0.0054398491235536535, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.20916985091752902, clip_y=109, include_settings=True, poly_degree=2, scaler=StandardScaler();, score=0.714 total time=   6.1s
# ...
# [CV 3/3] END basemodel__batch_size=293, basemodel__epochs=39, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=elu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.16404367274493936, basemodel__model__dropout2=0.11861854959512001, basemodel__model__dropout3=0.1, basemodel__model__dropout4=0.23887488692887693, basemodel__model__layer1=449, basemodel__model__layer2=190, basemodel__model__layer3=35, basemodel__model__layer4=159, basemodel__model__learning_rate=0.01, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.3939900339124375, clip_y=119, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.741 total time=   6.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=320, basemodel__epochs=30, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6851944863180514, basemodel__model__dropout2=0.3445258259006694, basemodel__model__dropout3=0.636310026171375, basemodel__model__dropout4=0.5642850455197131, basemodel__model__layer1=512, basemodel__model__layer2=334, basemodel__model__layer3=430, basemodel__model__layer4=237, basemodel__model__learning_rate=0.006734468893734489, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.37709857560975935, clip_y=92, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.735 total time=  13.0s
# [CV 2/3] END basemodel__batch_size=320, basemodel__epochs=30, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6851944863180514, basemodel__model__dropout2=0.3445258259006694, basemodel__model__dropout3=0.636310026171375, basemodel__model__dropout4=0.5642850455197131, basemodel__model__layer1=512, basemodel__model__layer2=334, basemodel__model__layer3=430, basemodel__model__layer4=237, basemodel__model__learning_rate=0.006734468893734489, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.37709857560975935, clip_y=92, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.641 total time=  21.7s
# [CV 3/3] END basemodel__batch_size=320, basemodel__epochs=30, basemodel__model__activation1=relu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=selu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6851944863180514, basemodel__model__dropout2=0.3445258259006694, basemodel__model__dropout3=0.636310026171375, basemodel__model__dropout4=0.5642850455197131, basemodel__model__layer1=512, basemodel__model__layer2=334, basemodel__model__layer3=430, basemodel__model__layer4=237, basemodel__model__learning_rate=0.006734468893734489, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.37709857560975935, clip_y=92, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.213 total time=  21.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=253, basemodel__epochs=22, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.14791018468264752, basemodel__model__dropout2=0.26164275936133446, basemodel__model__dropout3=0.7409369336203023, basemodel__model__dropout4=0.6395401774145799, basemodel__model__layer1=487, basemodel__model__layer2=303, basemodel__model__layer3=105, basemodel__model__layer4=420, basemodel__model__learning_rate=0.004492106990145859, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.5106832741900788, clip_y=110, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-0.001 total time=   5.7s
# [CV 2/3] END basemodel__batch_size=253, basemodel__epochs=22, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.14791018468264752, basemodel__model__dropout2=0.26164275936133446, basemodel__model__dropout3=0.7409369336203023, basemodel__model__dropout4=0.6395401774145799, basemodel__model__layer1=487, basemodel__model__layer2=303, basemodel__model__layer3=105, basemodel__model__layer4=420, basemodel__model__learning_rate=0.004492106990145859, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.5106832741900788, clip_y=110, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.229 total time=  11.6s
# [CV 3/3] END basemodel__batch_size=253, basemodel__epochs=22, basemodel__model__activation1=sigmoid, basemodel__model__activation2=selu, basemodel__model__activation3=sigmoid, basemodel__model__activation4=sigmoid, basemodel__model__dropout1=0.14791018468264752, basemodel__model__dropout2=0.26164275936133446, basemodel__model__dropout3=0.7409369336203023, basemodel__model__dropout4=0.6395401774145799, basemodel__model__layer1=487, basemodel__model__layer2=303, basemodel__model__layer3=105, basemodel__model__layer4=420, basemodel__model__learning_rate=0.004492106990145859, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.5106832741900788, clip_y=110, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.263 total time=  11.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=244, basemodel__epochs=50, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=elu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.8124970887369901, basemodel__model__dropout2=0.29587318198068435, basemodel__model__dropout3=0.11176916900266391, basemodel__model__dropout4=0.45657838299487474, basemodel__model__layer1=239, basemodel__model__layer2=221, basemodel__model__layer3=355, basemodel__model__layer4=55, basemodel__model__learning_rate=0.004115246574490714, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.18842294981104302, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.751 total time=  12.7s
# [CV 2/3] END basemodel__batch_size=244, basemodel__epochs=50, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=elu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.8124970887369901, basemodel__model__dropout2=0.29587318198068435, basemodel__model__dropout3=0.11176916900266391, basemodel__model__dropout4=0.45657838299487474, basemodel__model__layer1=239, basemodel__model__layer2=221, basemodel__model__layer3=355, basemodel__model__layer4=55, basemodel__model__learning_rate=0.004115246574490714, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.18842294981104302, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.743 total time=  21.4s
# [CV 3/3] END basemodel__batch_size=244, basemodel__epochs=50, basemodel__model__activation1=selu, basemodel__model__activation2=sigmoid, basemodel__model__activation3=elu, basemodel__model__activation4=elu, basemodel__model__dropout1=0.8124970887369901, basemodel__model__dropout2=0.29587318198068435, basemodel__model__dropout3=0.11176916900266391, basemodel__model__dropout4=0.45657838299487474, basemodel__model__layer1=239, basemodel__model__layer2=221, basemodel__model__layer3=355, basemodel__model__layer4=55, basemodel__model__learning_rate=0.004115246574490714, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.18842294981104302, clip_y=104, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.766 total time=  41.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=303, basemodel__epochs=4, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=tanh, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8967953240559162, basemodel__model__dropout2=0.6833453071556445, basemodel__model__dropout3=0.8758358292617712, basemodel__model__dropout4=0.45425182905580885, basemodel__model__layer1=244, basemodel__model__layer2=294, basemodel__model__layer3=246, basemodel__model__layer4=32, basemodel__model__learning_rate=0.0001, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.4245861509371208, clip_y=120, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-1.152 total time=   3.8s
# [CV 2/3] END basemodel__batch_size=303, basemodel__epochs=4, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=tanh, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8967953240559162, basemodel__model__dropout2=0.6833453071556445, basemodel__model__dropout3=0.8758358292617712, basemodel__model__dropout4=0.45425182905580885, basemodel__model__layer1=244, basemodel__model__layer2=294, basemodel__model__layer3=246, basemodel__model__layer4=32, basemodel__model__learning_rate=0.0001, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.4245861509371208, clip_y=120, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-0.863 total time=   2.9s
# [CV 3/3] END basemodel__batch_size=303, basemodel__epochs=4, basemodel__model__activation1=relu, basemodel__model__activation2=relu, basemodel__model__activation3=tanh, basemodel__model__activation4=selu, basemodel__model__dropout1=0.8967953240559162, basemodel__model__dropout2=0.6833453071556445, basemodel__model__dropout3=0.8758358292617712, basemodel__model__dropout4=0.45425182905580885, basemodel__model__layer1=244, basemodel__model__layer2=294, basemodel__model__layer3=246, basemodel__model__layer4=32, basemodel__model__learning_rate=0.0001, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, basemodel__validation_split=0.4245861509371208, clip_y=120, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=-1.792 total time=   3.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=210, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=elu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6368672525573011, basemodel__model__dropout2=0.2554611547704167, basemodel__model__dropout3=0.18643041522050346, basemodel__model__dropout4=0.4549503682997653, basemodel__model__layer1=456, basemodel__model__layer2=210, basemodel__model__layer3=107, basemodel__model__layer4=264, basemodel__model__learning_rate=0.0007588928392849534, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=107, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.596 total time=  19.4s
# [CV 2/3] END basemodel__batch_size=210, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=elu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6368672525573011, basemodel__model__dropout2=0.2554611547704167, basemodel__model__dropout3=0.18643041522050346, basemodel__model__dropout4=0.4549503682997653, basemodel__model__layer1=456, basemodel__model__layer2=210, basemodel__model__layer3=107, basemodel__model__layer4=264, basemodel__model__learning_rate=0.0007588928392849534, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=107, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.645 total time=  21.5s
# [CV 3/3] END basemodel__batch_size=210, basemodel__epochs=34, basemodel__model__activation1=sigmoid, basemodel__model__activation2=elu, basemodel__model__activation3=relu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.6368672525573011, basemodel__model__dropout2=0.2554611547704167, basemodel__model__dropout3=0.18643041522050346, basemodel__model__dropout4=0.4549503682997653, basemodel__model__layer1=456, basemodel__model__layer2=210, basemodel__model__layer3=107, basemodel__model__layer4=264, basemodel__model__learning_rate=0.0007588928392849534, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.1, clip_y=107, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.640 total time=  21.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END basemodel__batch_size=309, basemodel__epochs=24, basemodel__model__activation1=selu, basemodel__model__activation2=selu, basemodel__model__activation3=elu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.41016519861831957, basemodel__model__dropout2=0.18781645850327527, basemodel__model__dropout3=0.2435758914630303, basemodel__model__dropout4=0.5534996773415307, basemodel__model__layer1=446, basemodel__model__layer2=235, basemodel__model__layer3=256, basemodel__model__layer4=148, basemodel__model__learning_rate=0.007831847064569552, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2508216871573239, clip_y=109, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.753 total time=   8.8s
# [CV 2/3] END basemodel__batch_size=309, basemodel__epochs=24, basemodel__model__activation1=selu, basemodel__model__activation2=selu, basemodel__model__activation3=elu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.41016519861831957, basemodel__model__dropout2=0.18781645850327527, basemodel__model__dropout3=0.2435758914630303, basemodel__model__dropout4=0.5534996773415307, basemodel__model__layer1=446, basemodel__model__layer2=235, basemodel__model__layer3=256, basemodel__model__layer4=148, basemodel__model__learning_rate=0.007831847064569552, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2508216871573239, clip_y=109, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.526 total time=   9.4s
# [CV 3/3] END basemodel__batch_size=309, basemodel__epochs=24, basemodel__model__activation1=selu, basemodel__model__activation2=selu, basemodel__model__activation3=elu, basemodel__model__activation4=relu, basemodel__model__dropout1=0.41016519861831957, basemodel__model__dropout2=0.18781645850327527, basemodel__model__dropout3=0.2435758914630303, basemodel__model__dropout4=0.5534996773415307, basemodel__model__layer1=446, basemodel__model__layer2=235, basemodel__model__layer3=256, basemodel__model__layer4=148, basemodel__model__learning_rate=0.007831847064569552, basemodel__model__optim=<class 'keras.optimizers.optimizer_v2.adam.Adam'>, basemodel__validation_split=0.2508216871573239, clip_y=109, include_settings=True, poly_degree=3, scaler=StandardScaler();, score=0.753 total time=   6.7s
# Finished: 2022-10-25 10:58:49.054186

# %%
# print(bss.best_estimator_)
print(bss.best_score_)
print(bss.best_params_)
print("Finished:", datetime.datetime.now())
# Out:
# 0.7790003439779515
# OrderedDict([('basemodel__batch_size', 291), ('basemodel__epochs', 15), ('basemodel__model__activation1', 'selu'), ('basemodel__model__activation2', 'relu'), ('basemodel__model__activation3', 'relu'), ('basemodel__model__activation4', 'elu'), ('basemodel__model__dropout1', 0.43138482141909396), ('basemodel__model__dropout2', 0.1), ('basemodel__model__dropout3', 0.15985910954002355), ('basemodel__model__dropout4', 0.6832796453385808), ('basemodel__model__layer1', 466), ('basemodel__model__layer2', 194), ('basemodel__model__layer3', 345), ('basemodel__model__layer4', 98), ('basemodel__model__learning_rate', 0.005555768696453825), ('basemodel__model__optim', <class 'keras.optimizers.optimizer_v2.adam.Adam'>), ('basemodel__validation_split', 0.22076215606341174), ('clip_y', 93), ('include_settings', True), ('poly_degree', 3), ('scaler', StandardScaler())])
# Finished: 2022-10-25 10:58:49.076732

# %%
from skopt.plots import plot_convergence

plot_convergence(bss.optimizer_results_)
print("Finished:", datetime.datetime.now())
# Out:
# Finished: 2022-10-25 10:58:49.114681

# %%
bss.best_params_
# Out:
# OrderedDict([('basemodel__batch_size', 291),
#              ('basemodel__epochs', 15),
#              ('basemodel__model__activation1', 'selu'),
#              ('basemodel__model__activation2', 'relu'),
#              ('basemodel__model__activation3', 'relu'),
#              ('basemodel__model__activation4', 'elu'),
#              ('basemodel__model__dropout1', 0.43138482141909396),
#              ('basemodel__model__dropout2', 0.1),
#              ('basemodel__model__dropout3', 0.15985910954002355),
#              ('basemodel__model__dropout4', 0.6832796453385808),
#              ('basemodel__model__layer1', 466),
#              ('basemodel__model__layer2', 194),
#              ('basemodel__model__layer3', 345),
#              ('basemodel__model__layer4', 98),
#              ('basemodel__model__learning_rate', 0.005555768696453825),
#              ('basemodel__model__optim',
#               keras.optimizers.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.22076215606341174),
#              ('clip_y', 93),
#              ('include_settings', True),
#              ('poly_degree', 3),
#              ('scaler', StandardScaler())])

# %% [markdown]
# # MLP 1-layer

# %% [markdown]
# ## Linear RUL
#
# Score: 0.581174610036398
# Test: 0.
# ```
# ('basemodel__batch_size', 117),
#              ('basemodel__epochs', 42),
#              ('basemodel__model__activation1', 'tanh'),
#              ('basemodel__model__dropout1', 0.1),
#              ('basemodel__model__layer1', 512),
#              ('basemodel__model__learning_rate', 0.0034318227561347635),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.1),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL
# Score: 0.8184403480530235
# Test: 0.
# ```
# ('basemodel__batch_size', 32),
#              ('basemodel__epochs', 40),
#              ('basemodel__model__activation1', 'sigmoid'),
#              ('basemodel__model__dropout1', 0.1),
#              ('basemodel__model__layer1', 512),
#              ('basemodel__model__learning_rate', 0.01),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.1),
#              ('clip_y', 80),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Linear RUL + Poly
# Score: 0.5760357993360262
# Test: 0.
# ```
# ('basemodel__batch_size', 32),
#              ('basemodel__epochs', 50),
#              ('basemodel__model__activation1', 'elu'),
#              ('basemodel__model__dropout1', 0.5527766101177216),
#              ('basemodel__model__layer1', 61),
#              ('basemodel__model__learning_rate', 0.008905200618475653),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.168565014223427),
#              ('poly_degree', 3),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL + Poly
# Score: 0.746401337342355
# Test: 0.
# ```
# ('basemodel__batch_size', 32),
#              ('basemodel__epochs', 50),
#              ('basemodel__model__activation1', 'tanh'),
#              ('basemodel__model__dropout1', 0.10000000188658846),
#              ('basemodel__model__layer1', 512),
#              ('basemodel__model__learning_rate', 0.01),
#              ('basemodel__model__optim',
#               keras.optimizers.optimizer_v2.rmsprop.RMSprop),
#              ('basemodel__validation_split', 0.9),
#              ('clip_y', 80),
#              ('include_settings', True),
#              ('poly_degree', 2),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# # MLP 2-layer

# %% [markdown]
# ## Linear RUL
#
# Score: 0.5812000406687549
# Test: 0.
# ```
# ('basemodel__batch_size', 502),
#              ('basemodel__epochs', 19),
#              ('basemodel__model__activation1', 'relu'),
#              ('basemodel__model__activation2', 'elu'),
#              ('basemodel__model__dropout1', 0.537010358774788),
#              ('basemodel__model__dropout2', 0.639760677232973),
#              ('basemodel__model__layer1', 507),
#              ('basemodel__model__layer2', 151),
#              ('basemodel__model__learning_rate', 0.0055564604418504495),
#              ('basemodel__model__optim',
#               keras.optimizers.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.1),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL
# Score: 0.806487727981995
# Test: 0.
# ```
# ('basemodel__batch_size', 91),
#              ('basemodel__epochs', 50),
#              ('basemodel__model__activation1', 'tanh'),
#              ('basemodel__model__activation2', 'elu'),
#              ('basemodel__model__dropout1', 0.8099281594197152),
#              ('basemodel__model__dropout2', 0.3275285867415841),
#              ('basemodel__model__layer1', 61),
#              ('basemodel__model__layer2', 379),
#              ('basemodel__model__learning_rate', 0.0017750683313794622),
#              ('basemodel__model__optim', keras.optimizer_v2.rmsprop.RMSprop),
#              ('basemodel__validation_split', 0.41651962978418944),
#              ('clip_y', 80),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Linear RUL + Poly
# Score: 0.5749427963405077
# Test: 0.
# ```
# ('basemodel__batch_size', 108),
#              ('basemodel__epochs', 50),
#              ('basemodel__model__activation1', 'elu'),
#              ('basemodel__model__activation2', 'elu'),
#              ('basemodel__model__dropout1', 0.6853622426866657),
#              ('basemodel__model__dropout2', 0.4181419652000947),
#              ('basemodel__model__layer1', 392),
#              ('basemodel__model__layer2', 51),
#              ('basemodel__model__learning_rate', 0.007788469297925655),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.31679716488321474),
#              ('include_settings', True),
#              ('poly_degree', 3),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL + Poly
# Score: 0.8061999136353725
# Test: 0.
# ```
# ('basemodel__batch_size', 163),
#              ('basemodel__epochs', 32),
#              ('basemodel__model__activation1', 'selu'),
#              ('basemodel__model__activation2', 'relu'),
#              ('basemodel__model__dropout1', 0.1203636705927238),
#              ('basemodel__model__dropout2', 0.3108545284702169),
#              ('basemodel__model__layer1', 18),
#              ('basemodel__model__layer2', 364),
#              ('basemodel__model__learning_rate', 0.009076852273996898),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.14877733495106543),
#              ('clip_y', 87),
#              ('include_settings', True),
#              ('poly_degree', 2),
#              ('scaler', MinMaxScaler())
# ```

# %% [markdown]
# # MLP 3-layer

# %% [markdown]
# ## Linear RUL
#
# Score: 0.5854880998236767
# Test: 0.
# ```
# ('basemodel__batch_size', 200),
#              ('basemodel__epochs', 35),
#              ('basemodel__model__activation1', 'selu'),
#              ('basemodel__model__activation2', 'sigmoid'),
#              ('basemodel__model__activation3', 'sigmoid'),
#              ('basemodel__model__dropout1', 0.38531894797761335),
#              ('basemodel__model__dropout2', 0.2713124052618954),
#              ('basemodel__model__dropout3', 0.4032026752250656),
#              ('basemodel__model__layer1', 390),
#              ('basemodel__model__layer2', 371),
#              ('basemodel__model__layer3', 196),
#              ('basemodel__model__learning_rate', 0.00476952337213749),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.10948726819576624),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL
# Score: 0.7984364934573063
# Test: 0.
# ```
# ('basemodel__batch_size', 130),
#              ('basemodel__epochs', 47),
#              ('basemodel__model__activation1', 'relu'),
#              ('basemodel__model__activation2', 'elu'),
#              ('basemodel__model__activation3', 'selu'),
#              ('basemodel__model__dropout1', 0.6591215870708264),
#              ('basemodel__model__dropout2', 0.3075952959408218),
#              ('basemodel__model__dropout3', 0.3971628411684459),
#              ('basemodel__model__layer1', 444),
#              ('basemodel__model__layer2', 512),
#              ('basemodel__model__layer3', 381),
#              ('basemodel__model__learning_rate', 0.0035332717086087725),
#              ('basemodel__model__optim', keras.optimizer_v2.RMSprop.RMSprop),
#              ('basemodel__validation_split', 0.15776882704708337),
#              ('clip_y', 80),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Linear RUL + Poly
# Score: 0.5825762286758006
# Test: 0.
# ```
# ('basemodel__batch_size', 341),
#              ('basemodel__epochs', 34),
#              ('basemodel__model__activation1', 'tanh'),
#              ('basemodel__model__activation2', 'tanh'),
#              ('basemodel__model__activation3', 'selu'),
#              ('basemodel__model__dropout1', 0.7525277426098136),
#              ('basemodel__model__dropout2', 0.19508775114046617),
#              ('basemodel__model__dropout3', 0.1),
#              ('basemodel__model__layer1', 409),
#              ('basemodel__model__layer2', 185),
#              ('basemodel__model__layer3', 306),
#              ('basemodel__model__learning_rate', 0.0023786927659858437),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.10918862929162437),
#              ('include_settings', True),
#              ('poly_degree', 2),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL + Poly
# Score: 0.791357319322234
# Test: 0.
# ```
# ('basemodel__batch_size', 88),
#              ('basemodel__epochs', 6),
#              ('basemodel__model__activation1', 'selu'),
#              ('basemodel__model__activation2', 'tanh'),
#              ('basemodel__model__activation3', 'selu'),
#              ('basemodel__model__dropout1', 0.34493316079151415),
#              ('basemodel__model__dropout2', 0.45457085201703984),
#              ('basemodel__model__dropout3', 0.5997686385621787),
#              ('basemodel__model__layer1', 102),
#              ('basemodel__model__layer2', 155),
#              ('basemodel__model__layer3', 278),
#              ('basemodel__model__learning_rate', 0.008687869782338611),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.4969688376060647),
#              ('clip_y', 84),
#              ('include_settings', True),
#              ('poly_degree', 2),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# # MLP 4-layer

# %% [markdown]
# ## Linear RUL
#
# Score: 0.5879369617031984
# Test: 0.
# ```
# ('basemodel__batch_size', 319),
#              ('basemodel__epochs', 46),
#              ('basemodel__model__activation1', 'relu'),
#              ('basemodel__model__activation2', 'selu'),
#              ('basemodel__model__activation3', 'selu'),
#              ('basemodel__model__activation4', 'selu'),
#              ('basemodel__model__dropout1', 0.683753934762909),
#              ('basemodel__model__dropout2', 0.5369622665770732),
#              ('basemodel__model__dropout3', 0.658577790408341),
#              ('basemodel__model__dropout4', 0.805585273208486),
#              ('basemodel__model__layer1', 148),
#              ('basemodel__model__layer2', 428),
#              ('basemodel__model__layer3', 512),
#              ('basemodel__model__layer4', 510),
#              ('basemodel__model__learning_rate', 0.000866552772585896),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.1501923387205559),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL
# Score: 0.8031482586558986
# Test: 0.
# ```
# ('basemodel__batch_size', 186),
#              ('basemodel__epochs', 48),
#              ('basemodel__model__activation1', 'elu'),
#              ('basemodel__model__activation2', 'elu'),
#              ('basemodel__model__activation3', 'sigmoid'),
#              ('basemodel__model__activation4', 'relu'),
#              ('basemodel__model__dropout1', 0.3192129242485524),
#              ('basemodel__model__dropout2', 0.8716266059527173),
#              ('basemodel__model__dropout3', 0.9),
#              ('basemodel__model__dropout4', 0.1),
#              ('basemodel__model__layer1', 182),
#              ('basemodel__model__layer2', 505),
#              ('basemodel__model__layer3', 478),
#              ('basemodel__model__layer4', 16),
#              ('basemodel__model__learning_rate', 0.002811460975523156),
#              ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.1113203480919406),
#              ('clip_y', 80),
#              ('include_settings', True),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Linear RUL + Poly
# Score: 0.5429781834407112
# Test: 0.
# ```
# ('basemodel__batch_size', 108),
#              ('basemodel__epochs', 40),
#              ('basemodel__model__activation1', 'sigmoid'),
#              ('basemodel__model__activation2', 'relu'),
#              ('basemodel__model__activation3', 'relu'),
#              ('basemodel__model__activation4', 'sigmoid'),
#              ('basemodel__model__dropout1', 0.2621650470812381),
#              ('basemodel__model__dropout2', 0.1),
#              ('basemodel__model__dropout3', 0.5418530339407519),
#              ('basemodel__model__dropout4', 0.17380420072855723),
#              ('basemodel__model__layer1', 490),
#              ('basemodel__model__layer2', 84),
#              ('basemodel__model__layer3', 16),
#              ('basemodel__model__layer4', 109),
#              ('basemodel__model__learning_rate', 0.004902483950446228),
#              ('basemodel__model__optim', keras.optimizer_v2.rmsprop.RMSprop),
#              ('basemodel__validation_split', 0.4284401069475232),
#              ('include_settings', True),
#              ('poly_degree', 2),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# ## Non-Linear RUL + Poly
# Score: 0.7790003439779515
# Test: 0.
# ```
# ('basemodel__batch_size', 291),
#              ('basemodel__epochs', 15),
#              ('basemodel__model__activation1', 'selu'),
#              ('basemodel__model__activation2', 'relu'),
#              ('basemodel__model__activation3', 'relu'),
#              ('basemodel__model__activation4', 'elu'),
#              ('basemodel__model__dropout1', 0.43138482141909396),
#              ('basemodel__model__dropout2', 0.1),
#              ('basemodel__model__dropout3', 0.15985910954002355),
#              ('basemodel__model__dropout4', 0.6832796453385808),
#              ('basemodel__model__layer1', 466),
#              ('basemodel__model__layer2', 194),
#              ('basemodel__model__layer3', 345),
#              ('basemodel__model__layer4', 98),
#              ('basemodel__model__learning_rate', 0.005555768696453825),
#              ('basemodel__model__optim',
#               keras.optimizers.optimizer_v2.adam.Adam),
#              ('basemodel__validation_split', 0.22076215606341174),
#              ('clip_y', 93),
#              ('include_settings', True),
#              ('poly_degree', 3),
#              ('scaler', StandardScaler())
# ```

# %% [markdown]
# # MLP Tester

# %% [markdown]
# ```
# ('basemodel__batch_size', 32),
# ('basemodel__epochs', 50),
# ('basemodel__model__activation1', 'tanh'),
# ('basemodel__model__activation2', 'elu'),
# ('basemodel__model__dropout1', 0.1),
# ('basemodel__model__dropout2', 0.2107518503547072),
# ('basemodel__model__layer1', 168),
# ('basemodel__model__layer2', 428),
# ('basemodel__model__learning_rate', 0.01),
# ('basemodel__model__optim', keras.optimizer_v2.adam.Adam),
# ('basemodel__validation_split', 0.13631332793413636),
# ('clip_y', 80),
# ('scaler', MinMaxScaler())
# ```

# %%
CLIP=80

model = MLPWrapperRegressor(
        clip_y=CLIP, scaler=MinMaxScaler(),
        basemodel=
            KerasRegressor(model=create_model,
                           batch_size=32,
                           epochs=50,
                           model__activation1='tanh',
                           model__activation2='elu',
                           model__dropout1=0.1,
                           model__dropout2=0.2107518503547072, 
                           model__layer1=168, 
                           model__layer2=428, 
                           model__learning_rate=0.01,
                           model__optim=Adam,
                           validation_split=0.13631332793413636, 
                           verbose=0, callbacks=[es, printerCallback],
                           model__metrics=[RMSE(), R2()],
                           model__loss='mse',
                           print_summary=True
                           )
    )

# %%
model.fit(X_train_, y_train)
# Out:
# Model: "sequential_270"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_810 (Dense)           (None, 168)               3696
#
#  dropout_540 (Dropout)       (None, 168)               0
#
#  dense_811 (Dense)           (None, 428)               72332
#
#  dropout_541 (Dropout)       (None, 428)               0
#
#  dense_812 (Dense)           (None, 1)                 429
#
# =================================================================
# Total params: 76,457
# Trainable params: 76,457
# Non-trainable params: 0
# _________________________________________________________________
# E 1	: loss=172.561, rmse=13.136, r2=0.712; v_loss=98.196, v_rmse=9.909, v_r2=0.831;
# E 2	: loss=96.479, rmse=9.822, r2=0.839; v_loss=117.862, v_rmse=10.856, v_r2=0.797;
# E 3	: loss=92.964, rmse=9.642, r2=0.845; v_loss=100.306, v_rmse=10.015, v_r2=0.827;
# E 4	: loss=90.220, rmse=9.498, r2=0.849; v_loss=97.442, v_rmse=9.871, v_r2=0.832;
# E 5	: loss=92.239, rmse=9.604, r2=0.846; v_loss=96.405, v_rmse=9.819, v_r2=0.834;
# E 6	: loss=89.769, rmse=9.475, r2=0.850; v_loss=103.119, v_rmse=10.155, v_r2=0.822;
# E 7	: loss=89.589, rmse=9.465, r2=0.850; v_loss=96.367, v_rmse=9.817, v_r2=0.834;
# E 8	: loss=90.056, rmse=9.490, r2=0.850; v_loss=99.139, v_rmse=9.957, v_r2=0.829;
# E 9	: loss=90.041, rmse=9.489, r2=0.850; v_loss=98.825, v_rmse=9.941, v_r2=0.829;
# E 10	: loss=87.168, rmse=9.336, r2=0.854; v_loss=96.307, v_rmse=9.814, v_r2=0.834;
# E 11	: loss=87.184, rmse=9.337, r2=0.854; v_loss=88.517, v_rmse=9.408, v_r2=0.847;
# E 12	: loss=88.261, rmse=9.395, r2=0.853; v_loss=98.444, v_rmse=9.922, v_r2=0.830;
# E 13	: loss=88.111, rmse=9.387, r2=0.853; v_loss=92.551, v_rmse=9.620, v_r2=0.840;
# E 14	: loss=87.507, rmse=9.355, r2=0.854; v_loss=99.859, v_rmse=9.993, v_r2=0.828;
# E 15	: loss=86.567, rmse=9.304, r2=0.855; v_loss=90.369, v_rmse=9.506, v_r2=0.844;
# E 16	: loss=88.983, rmse=9.433, r2=0.851; v_loss=108.208, v_rmse=10.402, v_r2=0.813;
# E 17	: loss=86.140, rmse=9.281, r2=0.856; v_loss=96.990, v_rmse=9.848, v_r2=0.833;
# E 18	: loss=87.043, rmse=9.330, r2=0.855; v_loss=98.518, v_rmse=9.926, v_r2=0.830;
# E 19	: loss=86.823, rmse=9.318, r2=0.855; v_loss=95.459, v_rmse=9.770, v_r2=0.835;
# E 20	: loss=86.704, rmse=9.312, r2=0.855; v_loss=104.076, v_rmse=10.202, v_r2=0.820;
# E 21	: loss=86.354, rmse=9.293, r2=0.856; v_loss=105.567, v_rmse=10.275, v_r2=0.818;
# E 22	: loss=87.145, rmse=9.335, r2=0.854; v_loss=100.988, v_rmse=10.049, v_r2=0.826;
# MLPWrapperRegressor(basemodel=KerasRegressor(batch_size=32, callbacks=[<keras.callbacks.EarlyStopping object at 0x0000017111EAD250>, <keras.callbacks.LambdaCallback object at 0x0000017111EE4C10>], epochs=50, model=<function create_model at 0x0000017111F378B0>, model__activation1='tanh', model__activation2='elu', model__dropout1=0.1, model__dropout2=0.21075185035470...=428, model__learning_rate=0.01, model__loss='mse', model__metrics=[<keras.metrics.RootMeanSquaredError object at 0x00000172AC584D90>, <tensorflow_addons.metrics.r_square.RSquare object at 0x00000172AC584C10>], model__optim=<class 'keras.optimizer_v2.adam.Adam'>, print_summary=True, validation_split=0.13631332793413636, verbose=0),
#                     clip_y=80, scaler=MinMaxScaler())

# %%
model.score(X_test, reclipped_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-083753147b2c> in <module>
# ----> 1 model.score(X_test, reclipped_y)
#
# NameError: name 'reclipped_y' is not defined

# %%
# Scaling and formatting test data
test_sc = scale_test(X_test,model)
# test_wr = gen_test_wrapper(test_sc, SEQ_LENGTH)

# Clipping test labels
reclipped_y = y_test.copy()
if (CLIP > 0): reclipped_y=reclipped_y["RUL"].clip(upper=CLIP)

# Evaluation
eval.show_result(reclipped_y, model.basemodel.predict(test_sc))
# eval.show_result(reclipped_y, model.predict(X_test)) ## Doesn't work for LSTM
print("Finished:", datetime.datetime.now())
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-63-bf915f13081c> in <module>
#       1 # Scaling and formatting test data
# ----> 2 test_sc = scale_test(X_test,model)
#       3 # test_wr = gen_test_wrapper(test_sc, SEQ_LENGTH)
#       4
#       5 # Clipping test labels
#
# <ipython-input-34-e36179a483da> in scale_test(test, model)
#       4
#       5     # Apply polynomial features
# ----> 6     transf = model.polyft.transform(test2)
#       7     test2 = pd.DataFrame(transf,
#       8                          columns=model.polyft.get_feature_names_out())
#
# H:\anaconda3\lib\site-packages\sklearn\preprocessing\_polynomial.py in transform(self, X)
#     365             `csr_matrix`.
#     366         """
# --> 367         check_is_fitted(self)
#     368
#     369         X = self._validate_data(
#
# H:\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This PolynomialFeatures instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
